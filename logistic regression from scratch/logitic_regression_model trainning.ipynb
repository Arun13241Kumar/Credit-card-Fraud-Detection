# ...          ...       ...       ...  ...       ...       ...       ...
# 568625 -0.370393  0.189694 -0.938153  ... -0.751011  0.167503  0.419731
# 568626 -0.016935 -0.147733  0.483894  ... -0.550260  0.031874  0.388161
# 568627 -0.070958 -0.019997 -0.122048  ... -0.076417  0.140788  0.536523
# 568628  0.580568 -0.207723  0.893527  ...  0.288186 -0.060381 -0.195609
# 568629 -0.347613 -0.340814  0.253971  ... -0.621378  0.534853 -0.291514
#
#              V23       V24       V25       V26       V27       V28    Amount
# 226723  0.204480 -0.741707 -0.296137 -0.621493 -0.281639 -0.231126  14802.68
# 190243 -1.457513 -0.159896 -0.740358  0.043928  0.529154 -1.020540   1830.29
# 260217  0.060884 -1.905360 -0.219049  0.500373  0.415655  0.551322  21952.09
# 276186 -0.024042 -0.881658 -0.740845  0.382189  0.007474  0.043357  10555.04
# 11050  -0.033002 -0.009679  0.457914 -0.179149 -0.215450 -0.055858  22102.35
# ...          ...       ...       ...       ...       ...       ...       ...
# 568625  1.288249 -0.900861  0.560661 -0.006018  3.308968  0.081564   4394.16
# 568626 -0.154257 -0.846452 -0.153443  1.961398 -1.528642  1.704306   4653.40
# 568627 -0.211100 -0.448909  0.540073 -0.755836 -0.487540 -0.268741  23572.85
# 568628 -0.175488 -0.554643 -0.099669 -1.434931 -0.159269 -0.076251  10160.83
# 568629  0.157303  0.931030 -0.349423 -1.090974 -1.575113  0.722936  21493.92
#
# [284807 rows x 30 columns]

# %%
print(Y)
# Out:
# 226723    0
# 190243    0
# 260217    0
# 276186    0
# 11050     0
#          ..
# 568625    1
# 568626    1
# 568627    1
# 568628    1
# 568629    1
# Name: Class, Length: 284807, dtype: int64

# %% [markdown]
# Split the data into Training data & Testing Data

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=42)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (284807, 30) (227845, 30) (56962, 30)

# %% [markdown]
# Model Training

# %% [markdown]
# Logistic Regression

# %%
X_train = X_train.T
Y_train = Y_train.values.reshape(1, -1) # Use .values to get the underlying NumPy array and then reshape
X_test = X_test.T
Y_test = Y_test.values.reshape(1, -1) # -1 automatically calculates the appropriate dimension

# %%
print("Shape of X_train : ", X_train.shape)
print("Shape of Y_train : ", Y_train.shape)
print("Shape of X_test : ", X_test.shape)
print("Shape of Y_test : ", Y_test.shape)
# Out:
# Shape of X_train :  (30, 227845)
# Shape of Y_train :  (1, 227845)
# Shape of X_test :  (30, 56962)
# Shape of Y_test :  (1, 56962)

# %%
def sigmoid(x):
    return 1/(1 + np.exp(-x))

# %%
def model(X, Y, learning_rate, iterations):

    m = X_train.shape[1]
    n = X_train.shape[0]

    W = np.zeros((n,1))
    B = 0

    cost_list = []

    for i in range(iterations):

        Z = np.dot(W.T, X) + B
        A = sigmoid(Z)

        # cost function
        cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))

        # Gradient Descent
        dW = (1/m)*np.dot(A-Y, X.T)
        dB = (1/m)*np.sum(A - Y)

        W = W - learning_rate*dW.T
        B = B - learning_rate*dB

        # Keeping track of our cost function value
        cost_list.append(cost)

        if(i%(iterations/10) == 0):
            print("cost after ", i, "iteration is : ", cost)

    return W, B, cost_list

# %%
iterations = 1000
learning_rate = 0.0001
W, B, cost_list = model(X_train, Y_train, learning_rate = learning_rate, iterations = iterations)
# Out:
# cost after  0 iteration is :  0.6931471805599451
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# cost after  100 iteration is :  nan
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
# ...
#   return 1/(1 + np.exp(-x))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\3886325312.py:2: RuntimeWarning: overflow encountered in exp
#   return 1/(1 + np.exp(-x))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\3886325312.py:2: RuntimeWarning: overflow encountered in exp
#   return 1/(1 + np.exp(-x))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\3886325312.py:2: RuntimeWarning: overflow encountered in exp
#   return 1/(1 + np.exp(-x))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\3886325312.py:2: RuntimeWarning: overflow encountered in exp
#   return 1/(1 + np.exp(-x))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\3886325312.py:2: RuntimeWarning: overflow encountered in exp
#   return 1/(1 + np.exp(-x))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\3886325312.py:2: RuntimeWarning: overflow encountered in exp
#   return 1/(1 + np.exp(-x))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\3886325312.py:2: RuntimeWarning: overflow encountered in exp
#   return 1/(1 + np.exp(-x))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\3886325312.py:2: RuntimeWarning: overflow encountered in exp
#   return 1/(1 + np.exp(-x))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\3886325312.py:2: RuntimeWarning: overflow encountered in exp
#   return 1/(1 + np.exp(-x))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\3886325312.py:2: RuntimeWarning: overflow encountered in exp
#   return 1/(1 + np.exp(-x))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\3886325312.py:2: RuntimeWarning: overflow encountered in exp
#   return 1/(1 + np.exp(-x))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\3886325312.py:2: RuntimeWarning: overflow encountered in exp
#   return 1/(1 + np.exp(-x))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\3886325312.py:2: RuntimeWarning: overflow encountered in exp
#   return 1/(1 + np.exp(-x))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\3886325312.py:2: RuntimeWarning: overflow encountered in exp
#   return 1/(1 + np.exp(-x))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\3886325312.py:2: RuntimeWarning: overflow encountered in exp
#   return 1/(1 + np.exp(-x))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\3886325312.py:2: RuntimeWarning: overflow encountered in exp
#   return 1/(1 + np.exp(-x))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\3886325312.py:2: RuntimeWarning: overflow encountered in exp
#   return 1/(1 + np.exp(-x))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\3886325312.py:2: RuntimeWarning: overflow encountered in exp
#   return 1/(1 + np.exp(-x))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\3886325312.py:2: RuntimeWarning: overflow encountered in exp
#   return 1/(1 + np.exp(-x))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\3886325312.py:2: RuntimeWarning: overflow encountered in exp
#   return 1/(1 + np.exp(-x))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\3886325312.py:2: RuntimeWarning: overflow encountered in exp
#   return 1/(1 + np.exp(-x))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\3886325312.py:2: RuntimeWarning: overflow encountered in exp
#   return 1/(1 + np.exp(-x))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\3886325312.py:2: RuntimeWarning: overflow encountered in exp
#   return 1/(1 + np.exp(-x))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\3886325312.py:2: RuntimeWarning: overflow encountered in exp
#   return 1/(1 + np.exp(-x))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\3886325312.py:2: RuntimeWarning: overflow encountered in exp
#   return 1/(1 + np.exp(-x))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\3886325312.py:2: RuntimeWarning: overflow encountered in exp
#   return 1/(1 + np.exp(-x))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\3886325312.py:2: RuntimeWarning: overflow encountered in exp
#   return 1/(1 + np.exp(-x))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\3886325312.py:2: RuntimeWarning: overflow encountered in exp
#   return 1/(1 + np.exp(-x))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\3886325312.py:2: RuntimeWarning: overflow encountered in exp
#   return 1/(1 + np.exp(-x))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\3886325312.py:2: RuntimeWarning: overflow encountered in exp
#   return 1/(1 + np.exp(-x))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\3886325312.py:2: RuntimeWarning: overflow encountered in exp
#   return 1/(1 + np.exp(-x))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\3886325312.py:2: RuntimeWarning: overflow encountered in exp
#   return 1/(1 + np.exp(-x))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\732349170.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))

# %%
def accuracy(X, Y, W, B):

    Z = np.dot(W.T, X) + B
    A = sigmoid(Z)

    A = A > 0.5

    A = np.array(A, dtype = 'int64')

    acc = (1 - np.sum(np.absolute(A - Y))/Y.shape[1])*100

    print("Accuracy of the model is : ", round(acc, 2), "%")

# %%
accuracy(X_test, Y_test, W, B)
# Out:
# Accuracy of the model is :  99.8 %
# C:\Users\arunk\AppData\Local\Temp\ipykernel_6780\3886325312.py:2: RuntimeWarning: overflow encountered in exp
#   return 1/(1 + np.exp(-x))
